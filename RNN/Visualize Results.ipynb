# %%
import pickle
import numpy as np
import pylab as pl
# %matplotlib inline 
import seaborn as sns
import pandas as pd

# %%
stats = pickle.load(open('testResults/Run_rnn_9.stats', 'rb'))
print (len(stats[0]))
stats = np.array(stats)

x = []
y = []
mu = []
print(stats.shape)
for e in range(stats.shape[0]):
    x += [e] * stats.shape[1]
    y += list(stats[e])
    mu.append(np.mean(y))
data = pd.DataFrame({'epoch':x, 'accuracy':y})
# Out:
# 30
# (10, 30)

# %%
mus = pd.DataFrame({'epoch':np.arange(stats.shape[0]), 'accuracy':mu})
print(mus)
# Out:
#     accuracy  epoch
# 0  83.927778      0
# 1  83.408433      1
# 2  79.984987      2
# 3  82.399504      3
# 4  83.556905      4
# 5  84.601488      5
# 6  85.436054      6
# 7  84.650818      7
# 8  83.969070      8
# 9  83.040397      9

# %%
max_i = np.argmax(y)
x[max_i], y[max_i]
pl.figure(figsize=(8,8))
sns.boxplot(x="epoch", y="accuracy", data=data)
# sns.swarmplot(x="epoch", y="accuracy", data=data)
sns.stripplot(x="epoch", y="accuracy", data=mus, jitter=True, size=8, color=".1", linewidth=0)
# label = 'Max accuracy:{}%'.format(y[max_i])
# pl.plot([y[max_i]]*10, label=label)
# pl.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

print(y[max_i])
# Out:
# 99.75

# %%
sns.distplot(y, bins=20, kde=False, rug=False)

# %%
max_i = np.argmax(y)
x[max_i], y[max_i]
pl.figure(figsize=(8,8))
# sns.boxplot(x="epoch", y="accuracy", data=data)
sns.swarmplot(x="epoch", y="accuracy", data=data)
sns.stripplot(x="epoch", y="accuracy", data=mus, jitter=True, size=8, color=".4", linewidth=0)
label = 'Max accuracy:{}%'.format(y[max_i])
pl.plot([y[max_i]]*10, label=label)
pl.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

print(y[max_i])
# Out:
# 99.75

# %%
# !ls
# Out:
# backup	       tourney_0.stats	tourney_4.stats  tourney_8.stats
# experiment.py  tourney_1.pop	tourney_5.pop	 tourney_9.pop
# gp.py	       tourney_1.stats	tourney_5.stats  tourney_9.stats
# netbuilder.py  tourney_2.pop	tourney_6.pop	 Visualize Results.ipynb
# __pycache__    tourney_2.stats	tourney_6.stats  visualResult.py
# rNNBack.py     tourney_3.pop	tourney_7.pop	 worker.py
# rnnNeuro.py    tourney_3.stats	tourney_7.stats
# tourney_0.pop  tourney_4.pop	tourney_8.pop
